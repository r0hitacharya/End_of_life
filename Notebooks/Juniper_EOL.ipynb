# %% [markdown]
# Juniper End of Life
#
# - Extracts the URL pattern for Juniper end-of-life (EOL) pages and uses regular expressions to extract the product lines from each page.
# - Loops through each EOL page and extracts the tables containing hardware or product information.
# - Transforms the data to get a unique SKU per row using the `assign`, `explode`, and `reset_index` methods.
# - Cleans the data by removing unwanted characters and converting data types.
# - Outputs the cleaned data to a CSV file for further analysis.
#
# The script is designed to extract hardware or product information for Juniper products and prepare the data for further analysis.

# %% [markdown]
# # Libraries

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Send a GET request to the URL
url = "https://support.juniper.net/support/eol/"
response = requests.get(url)

# Extract all Hardware URL in the Juniper EOL page
url_pattern = r'"/support/eol/product/.*?"'
product_urls = re.findall(url_pattern, response.text)

# Extract all Software URL in the Juniper EOL page
url_pattern_software = r'"/support/eol/software/.*?"'
software_urls = re.findall(url_pattern_software, response.text)

# %% [markdown]
# ## Scraping individual Product Lines

# %%
# Define regular expression patterns

pattern_table = re.compile(r'<table\b[^>]*>(.*?)</table>', re.DOTALL)
pattern_tr = re.compile(r'<tr>(.*?)</tr>', re.DOTALL)
pattern_td = re.compile(r'<td>(.*?)</td>', re.DOTALL)
pattern_th = re.compile(r'<th>(.*?)</th>', re.DOTALL)
pattern_a = re.compile(r'<a href="(.*?)">(.*?)</a>', re.DOTALL)

# %%
# Please note corero_tdd products are not in the same format as the rest of the products hence not included in the final dataframe
holder_df = pd.DataFrame()
final_df = pd.DataFrame()

for url in product_urls:
    url = ('https://support.juniper.net'+url.strip('\"'))
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    # Extract the table contents using regular expressions
    match_table = pattern_table.search(response.text)
    if match_table:
        tbody_html = match_table.group(1)
        rows = pattern_tr.findall(tbody_html)
        header = pattern_th.findall(rows[0])
        header = [re.sub('<br />', ' ', h) for h in header]
        data = []
        for row in rows[1:]:
            cols = pattern_td.findall(row)
            cols = [pattern_a.sub(r'\2', col) for col in cols]
            data.append(dict(zip(header, cols)))
            print(url,"---->",len(data))
            holder_df = pd.DataFrame(data) #a holder dataframe to hold the URL in contention
            final_df = pd.concat([final_df, holder_df], ignore_index=True)
            
    else:
        print('Table not found, Something went wrong')
# Out:
# https://support.juniper.net/support/eol/product/acx_series/ ----> 1
# https://support.juniper.net/support/eol/product/acx_series/ ----> 2
# https://support.juniper.net/support/eol/product/acx_series/ ----> 3
# https://support.juniper.net/support/eol/product/acx_series/ ----> 4
# https://support.juniper.net/support/eol/product/acx_series/ ----> 5
# https://support.juniper.net/support/eol/product/acx_series/ ----> 6
# https://support.juniper.net/support/eol/product/acx_series/ ----> 7
# https://support.juniper.net/support/eol/product/acx_series/ ----> 8
# https://support.juniper.net/support/eol/product/acx_series/ ----> 9
# https://support.juniper.net/support/eol/product/acx_series/ ----> 10
# https://support.juniper.net/support/eol/product/ax_series/ ----> 1
# https://support.juniper.net/support/eol/product/bx_series/ ----> 1
# https://support.juniper.net/support/eol/product/bti_series/ ----> 1
# https://support.juniper.net/support/eol/product/bti_series/ ----> 2
# https://support.juniper.net/support/eol/product/bti_series/ ----> 3
# https://support.juniper.net/support/eol/product/bti_series/ ----> 4
# https://support.juniper.net/support/eol/product/bti_series/ ----> 5
# https://support.juniper.net/support/eol/product/bti_series/ ----> 6
# https://support.juniper.net/support/eol/product/bti_series/ ----> 7
# https://support.juniper.net/support/eol/product/bti_series/ ----> 8
# https://support.juniper.net/support/eol/product/bti_series/ ----> 9
# https://support.juniper.net/support/eol/product/bti_series/ ----> 10
# https://support.juniper.net/support/eol/product/bti_series/ ----> 11
# https://support.juniper.net/support/eol/product/bti_series/ ----> 12
# https://support.juniper.net/support/eol/product/bti_series/ ----> 13
# https://support.juniper.net/support/eol/product/bti_series/ ----> 14
# https://support.juniper.net/support/eol/product/bti_series/ ----> 15
# https://support.juniper.net/support/eol/product/bti_series/ ----> 16
# https://support.juniper.net/support/eol/product/bti_series/ ----> 17
# https://support.juniper.net/support/eol/product/c_series/ ----> 1
# https://support.juniper.net/support/eol/product/c_series/ ----> 2
# https://support.juniper.net/support/eol/product/c_series/ ----> 3
# https://support.juniper.net/support/eol/product/c_series/ ----> 4
# https://support.juniper.net/support/eol/product/contrail/ ----> 1
# https://support.juniper.net/support/eol/product/contrail/ ----> 2
# https://support.juniper.net/support/eol/product/contrail/ ----> 3
# https://support.juniper.net/support/eol/product/contrail/ ----> 4
# https://support.juniper.net/support/eol/product/contrail/ ----> 5
# https://support.juniper.net/support/eol/product/contrail/ ----> 6
# https://support.juniper.net/support/eol/product/contrail_insights/ ----> 1
# https://support.juniper.net/support/eol/product/cso/ ----> 1
# https://support.juniper.net/support/eol/product/cso/ ----> 2
# Table not found, Something went wrong
# https://support.juniper.net/support/eol/product/crpd/ ----> 1
# https://support.juniper.net/support/eol/product/cse_series/ ----> 1
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 1
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 2
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 3
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 4
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 5
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 6
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 7
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 8
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 9
# https://support.juniper.net/support/eol/product/ctp_series/ ----> 10
# https://support.juniper.net/support/eol/product/ddos_secure_hw/ ----> 1
# https://support.juniper.net/support/eol/product/dx_series/ ----> 1
# https://support.juniper.net/support/eol/product/dx_series/ ----> 2
# https://support.juniper.net/support/eol/product/dx_series/ ----> 3
# https://support.juniper.net/support/eol/product/dx_series/ ----> 4
# https://support.juniper.net/support/eol/product/e_series/ ----> 1
# https://support.juniper.net/support/eol/product/e_series/ ----> 2
# https://support.juniper.net/support/eol/product/e_series/ ----> 3
# https://support.juniper.net/support/eol/product/e_series/ ----> 4
# https://support.juniper.net/support/eol/product/e_series/ ----> 5
# https://support.juniper.net/support/eol/product/e_series/ ----> 6
# https://support.juniper.net/support/eol/product/e_series/ ----> 7
# https://support.juniper.net/support/eol/product/e_series/ ----> 8
# https://support.juniper.net/support/eol/product/e_series/ ----> 9
# https://support.juniper.net/support/eol/product/e_series/ ----> 10
# https://support.juniper.net/support/eol/product/e_series/ ----> 11
# https://support.juniper.net/support/eol/product/e_series/ ----> 12
# https://support.juniper.net/support/eol/product/e_series/ ----> 13
# https://support.juniper.net/support/eol/product/e_series/ ----> 14
# https://support.juniper.net/support/eol/product/e_series/ ----> 15
# https://support.juniper.net/support/eol/product/e_series/ ----> 16
# https://support.juniper.net/support/eol/product/e_series/ ----> 17
# https://support.juniper.net/support/eol/product/e_series/ ----> 18
# https://support.juniper.net/support/eol/product/e_series/ ----> 19
# https://support.juniper.net/support/eol/product/e_series/ ----> 20
# https://support.juniper.net/support/eol/product/e_series/ ----> 21
# https://support.juniper.net/support/eol/product/e_series/ ----> 22
# https://support.juniper.net/support/eol/product/e_series/ ----> 23
# https://support.juniper.net/support/eol/product/e_series/ ----> 24
# https://support.juniper.net/support/eol/product/e_series/ ----> 25
# https://support.juniper.net/support/eol/product/e_series/ ----> 26
# https://support.juniper.net/support/eol/product/e_series/ ----> 27
# https://support.juniper.net/support/eol/product/e_series/ ----> 28
# https://support.juniper.net/support/eol/product/e_series/ ----> 29
# https://support.juniper.net/support/eol/product/e_series/ ----> 30
# https://support.juniper.net/support/eol/product/e_series/ ----> 31
# https://support.juniper.net/support/eol/product/e_series/ ----> 32
# https://support.juniper.net/support/eol/product/e_series/ ----> 33
# https://support.juniper.net/support/eol/product/e_series/ ----> 34
# https://support.juniper.net/support/eol/product/e_series/ ----> 35
# https://support.juniper.net/support/eol/product/ex_series/ ----> 1
# https://support.juniper.net/support/eol/product/ex_series/ ----> 2
# https://support.juniper.net/support/eol/product/ex_series/ ----> 3
# https://support.juniper.net/support/eol/product/ex_series/ ----> 4
# https://support.juniper.net/support/eol/product/ex_series/ ----> 5
# https://support.juniper.net/support/eol/product/ex_series/ ----> 6
# https://support.juniper.net/support/eol/product/ex_series/ ----> 7
# https://support.juniper.net/support/eol/product/ex_series/ ----> 8
# https://support.juniper.net/support/eol/product/ex_series/ ----> 9
# https://support.juniper.net/support/eol/product/ex_series/ ----> 10
# https://support.juniper.net/support/eol/product/ex_series/ ----> 11
# https://support.juniper.net/support/eol/product/ex_series/ ----> 12
# https://support.juniper.net/support/eol/product/ex_series/ ----> 13
# https://support.juniper.net/support/eol/product/ex_series/ ----> 14
# https://support.juniper.net/support/eol/product/ex_series/ ----> 15
# https://support.juniper.net/support/eol/product/ex_series/ ----> 16
# https://support.juniper.net/support/eol/product/ex_series/ ----> 17
# https://support.juniper.net/support/eol/product/ex_series/ ----> 18
# https://support.juniper.net/support/eol/product/ex_series/ ----> 19
# https://support.juniper.net/support/eol/product/ex_series/ ----> 20
# https://support.juniper.net/support/eol/product/ex_series/ ----> 21
# https://support.juniper.net/support/eol/product/ex_series/ ----> 22
# https://support.juniper.net/support/eol/product/ex_series/ ----> 23
# https://support.juniper.net/support/eol/product/j_series/ ----> 1
# https://support.juniper.net/support/eol/product/j_series/ ----> 2
# https://support.juniper.net/support/eol/product/j_series/ ----> 3
# https://support.juniper.net/support/eol/product/j_series/ ----> 4
# https://support.juniper.net/support/eol/product/j_series/ ----> 5
# https://support.juniper.net/support/eol/product/jatp/ ----> 1
# https://support.juniper.net/support/eol/product/jatp/ ----> 2
# https://support.juniper.net/support/eol/product/jcs1200/ ----> 1
# https://support.juniper.net/support/eol/product/jcs1200/ ----> 2
# https://support.juniper.net/support/eol/product/jcs1200/ ----> 3
# https://support.juniper.net/support/eol/product/jrim_hw/ ----> 1
# https://support.juniper.net/support/eol/product/juniper_ap_series/ ----> 1
# https://support.juniper.net/support/eol/product/juniper_ap_series/ ----> 2
# https://support.juniper.net/support/eol/product/apstra/ ----> 1
# https://support.juniper.net/support/eol/product/apstra/ ----> 2
# https://support.juniper.net/support/eol/product/jcwp/ ----> 1
# https://support.juniper.net/support/eol/product/junos_space_hw/ ----> 1
# https://support.juniper.net/support/eol/product/junos_space_csd/ ----> 1
# https://support.juniper.net/support/eol/product/junos_space_csd/ ----> 2
# https://support.juniper.net/support/eol/product/junos_space_platform/ ----> 1
# https://support.juniper.net/support/eol/product/ln_series/ ----> 1
# https://support.juniper.net/support/eol/product/ln_series/ ----> 2
# https://support.juniper.net/support/eol/product/ln_series/ ----> 3
# https://support.juniper.net/support/eol/product/m_series/ ----> 1
# https://support.juniper.net/support/eol/product/m_series/ ----> 2
# https://support.juniper.net/support/eol/product/m_series/ ----> 3
# https://support.juniper.net/support/eol/product/m_series/ ----> 4
# https://support.juniper.net/support/eol/product/m_series/ ----> 5
# https://support.juniper.net/support/eol/product/m_series/ ----> 6
# https://support.juniper.net/support/eol/product/m_series/ ----> 7
# https://support.juniper.net/support/eol/product/m_series/ ----> 8
# https://support.juniper.net/support/eol/product/m_series/ ----> 9
# https://support.juniper.net/support/eol/product/m_series/ ----> 10
# https://support.juniper.net/support/eol/product/m_series/ ----> 11
# https://support.juniper.net/support/eol/product/m_series/ ----> 12
# https://support.juniper.net/support/eol/product/m_series/ ----> 13
# https://support.juniper.net/support/eol/product/m_series/ ----> 14
# https://support.juniper.net/support/eol/product/m_series/ ----> 15
# https://support.juniper.net/support/eol/product/m_series/ ----> 16
# https://support.juniper.net/support/eol/product/m_series/ ----> 17
# https://support.juniper.net/support/eol/product/m_series/ ----> 18
# https://support.juniper.net/support/eol/product/m_series/ ----> 19
# https://support.juniper.net/support/eol/product/m_series/ ----> 20
# https://support.juniper.net/support/eol/product/m_series/ ----> 21
# https://support.juniper.net/support/eol/product/m_series/ ----> 22
# https://support.juniper.net/support/eol/product/m_series/ ----> 23
# https://support.juniper.net/support/eol/product/m_series/ ----> 24
# https://support.juniper.net/support/eol/product/m_series/ ----> 25
# https://support.juniper.net/support/eol/product/m_series/ ----> 26
# https://support.juniper.net/support/eol/product/m_series/ ----> 27
# https://support.juniper.net/support/eol/product/m_series/ ----> 28
# https://support.juniper.net/support/eol/product/m_series/ ----> 29
# https://support.juniper.net/support/eol/product/m_series/ ----> 30
# https://support.juniper.net/support/eol/product/m_series/ ----> 31
# https://support.juniper.net/support/eol/product/m_series/ ----> 32
# https://support.juniper.net/support/eol/product/m_series/ ----> 33
# https://support.juniper.net/support/eol/product/m_series/ ----> 34
# https://support.juniper.net/support/eol/product/m_series/ ----> 35
# https://support.juniper.net/support/eol/product/m_series/ ----> 36
# https://support.juniper.net/support/eol/product/m_series/ ----> 37
# https://support.juniper.net/support/eol/product/m_series/ ----> 38
# https://support.juniper.net/support/eol/product/m_series/ ----> 39
# https://support.juniper.net/support/eol/product/m_series/ ----> 40
# https://support.juniper.net/support/eol/product/m_series/ ----> 41
# https://support.juniper.net/support/eol/product/m_series/ ----> 42
# https://support.juniper.net/support/eol/product/m_series/ ----> 43
# https://support.juniper.net/support/eol/product/m_series/ ----> 44
# https://support.juniper.net/support/eol/product/m_series/ ----> 45
# https://support.juniper.net/support/eol/product/m_series/ ----> 46
# https://support.juniper.net/support/eol/product/m_series/ ----> 47
# https://support.juniper.net/support/eol/product/m_series/ ----> 48
# https://support.juniper.net/support/eol/product/m_series/ ----> 49
# https://support.juniper.net/support/eol/product/m_series/ ----> 50
# https://support.juniper.net/support/eol/product/m_series/ ----> 51
# https://support.juniper.net/support/eol/product/m_series/ ----> 52
# https://support.juniper.net/support/eol/product/m_series/ ----> 53
# https://support.juniper.net/support/eol/product/m_series/ ----> 54
# https://support.juniper.net/support/eol/product/m_series/ ----> 55
# https://support.juniper.net/support/eol/product/m_series/ ----> 56
# https://support.juniper.net/support/eol/product/m_series/ ----> 57
# https://support.juniper.net/support/eol/product/m_series/ ----> 58
# https://support.juniper.net/support/eol/product/m_series/ ----> 59
# https://support.juniper.net/support/eol/product/m_series/ ----> 60
# https://support.juniper.net/support/eol/product/m_series/ ----> 61
# https://support.juniper.net/support/eol/product/m_series/ ----> 62
# https://support.juniper.net/support/eol/product/m_series/ ----> 63
# https://support.juniper.net/support/eol/product/m_series/ ----> 64
# https://support.juniper.net/support/eol/product/m_series/ ----> 65
# https://support.juniper.net/support/eol/product/m_series/ ----> 66
# https://support.juniper.net/support/eol/product/m_series/ ----> 67
# https://support.juniper.net/support/eol/product/m_series/ ----> 68
# https://support.juniper.net/support/eol/product/m_series/ ----> 69
# https://support.juniper.net/support/eol/product/m_series/ ----> 70
# https://support.juniper.net/support/eol/product/m_series/ ----> 71
# https://support.juniper.net/support/eol/product/m_series/ ----> 72
# https://support.juniper.net/support/eol/product/m_series/ ----> 73
# https://support.juniper.net/support/eol/product/m_series/ ----> 74
# https://support.juniper.net/support/eol/product/m_series/ ----> 75
# https://support.juniper.net/support/eol/product/m_series/ ----> 76
# https://support.juniper.net/support/eol/product/m_series/ ----> 77
# https://support.juniper.net/support/eol/product/m_series/ ----> 78
# https://support.juniper.net/support/eol/product/m_series/ ----> 79
# https://support.juniper.net/support/eol/product/m_series/ ----> 80
# https://support.juniper.net/support/eol/product/m_series/ ----> 81
# https://support.juniper.net/support/eol/product/m_series/ ----> 82
# https://support.juniper.net/support/eol/product/m_series/ ----> 83
# https://support.juniper.net/support/eol/product/m_series/ ----> 84
# https://support.juniper.net/support/eol/product/m_series/ ----> 85
# https://support.juniper.net/support/eol/product/m_series/ ----> 86
# https://support.juniper.net/support/eol/product/m_series/ ----> 87
# https://support.juniper.net/support/eol/product/m_series/ ----> 88
# https://support.juniper.net/support/eol/product/m_series/ ----> 89
# https://support.juniper.net/support/eol/product/m_series/ ----> 90
# https://support.juniper.net/support/eol/product/m_series/ ----> 91
# https://support.juniper.net/support/eol/product/m_series/ ----> 92
# https://support.juniper.net/support/eol/product/m_series/ ----> 93
# https://support.juniper.net/support/eol/product/m_series/ ----> 94
# https://support.juniper.net/support/eol/product/m_series/ ----> 95
# https://support.juniper.net/support/eol/product/m_series/ ----> 96
# https://support.juniper.net/support/eol/product/m_series/ ----> 97
# https://support.juniper.net/support/eol/product/m_series/ ----> 98
# https://support.juniper.net/support/eol/product/m_series/ ----> 99
# https://support.juniper.net/support/eol/product/m_series/ ----> 100
# https://support.juniper.net/support/eol/product/m_series/ ----> 101
# https://support.juniper.net/support/eol/product/m_series/ ----> 102
# https://support.juniper.net/support/eol/product/m_series/ ----> 103
# https://support.juniper.net/support/eol/product/m_series/ ----> 104
# https://support.juniper.net/support/eol/product/m_series/ ----> 105
# https://support.juniper.net/support/eol/product/m_series/ ----> 106
# https://support.juniper.net/support/eol/product/m_series/ ----> 107
# https://support.juniper.net/support/eol/product/m_series/ ----> 108
# https://support.juniper.net/support/eol/product/m_series/ ----> 109
# https://support.juniper.net/support/eol/product/m_series/ ----> 110
# https://support.juniper.net/support/eol/product/m_series/ ----> 111
# https://support.juniper.net/support/eol/product/m_series/ ----> 112
# https://support.juniper.net/support/eol/product/m_series/ ----> 113
# https://support.juniper.net/support/eol/product/m_series/ ----> 114
# https://support.juniper.net/support/eol/product/m_series/ ----> 115
# https://support.juniper.net/support/eol/product/m_series/ ----> 116
# https://support.juniper.net/support/eol/product/m_series/ ----> 117
# https://support.juniper.net/support/eol/product/m_series/ ----> 118
# https://support.juniper.net/support/eol/product/m_series/ ----> 119
# https://support.juniper.net/support/eol/product/netrounds/ ----> 1
# https://support.juniper.net/support/eol/product/netrounds/ ----> 2
# https://support.juniper.net/support/eol/product/netrounds/ ----> 3
# https://support.juniper.net/support/eol/product/netrounds/ ----> 4
# https://support.juniper.net/support/eol/product/netrounds/ ----> 5
# https://support.juniper.net/support/eol/product/netrounds/ ----> 6
# https://support.juniper.net/support/eol/product/netrounds/ ----> 7
# https://support.juniper.net/support/eol/product/netrounds/ ----> 8
# https://support.juniper.net/support/eol/product/netrounds/ ----> 9
# https://support.juniper.net/support/eol/product/netrounds/ ----> 10
# https://support.juniper.net/support/eol/product/netrounds/ ----> 11
# https://support.juniper.net/support/eol/product/netrounds/ ----> 12
# https://support.juniper.net/support/eol/product/netrounds/ ----> 13
# https://support.juniper.net/support/eol/product/netrounds/ ----> 14
# https://support.juniper.net/support/eol/product/netrounds/ ----> 15
# https://support.juniper.net/support/eol/product/netrounds/ ----> 16
# https://support.juniper.net/support/eol/product/netrounds/ ----> 17
# https://support.juniper.net/support/eol/product/netrounds/ ----> 18
# https://support.juniper.net/support/eol/product/netrounds/ ----> 19
# https://support.juniper.net/support/eol/product/netrounds/ ----> 20
# https://support.juniper.net/support/eol/product/netscreen_idp_hw/ ----> 1
# https://support.juniper.net/support/eol/product/netscreen_idp_hw/ ----> 2
# https://support.juniper.net/support/eol/product/netscreen_idp_hw/ ----> 3
# https://support.juniper.net/support/eol/product/netscreen_idp_hw/ ----> 4
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 1
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 2
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 3
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 4
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 5
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 6
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 7
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 8
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 9
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 10
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 11
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 12
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 13
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 14
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 15
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 16
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 17
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 18
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 19
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 20
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 21
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 22
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 23
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 24
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 25
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 26
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 27
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 28
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 29
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 30
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 31
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 32
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 33
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 34
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 35
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 36
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 37
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 38
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 39
# https://support.juniper.net/support/eol/product/netscreen_hw/ ----> 40
# https://support.juniper.net/support/eol/product/nfx_series/ ----> 1
# https://support.juniper.net/support/eol/product/nfx_series/ ----> 2
# https://support.juniper.net/support/eol/product/nfx_series/ ----> 3
# https://support.juniper.net/support/eol/product/northstar/ ----> 1
# https://support.juniper.net/support/eol/product/northstar/ ----> 2
# https://support.juniper.net/support/eol/product/nsm_hw/ ----> 1
# https://support.juniper.net/support/eol/product/nsm_hw/ ----> 2
# https://support.juniper.net/support/eol/product/nsm_hw/ ----> 3
# https://support.juniper.net/support/eol/product/nsm_hw/ ----> 4
# https://support.juniper.net/support/eol/product/nsm_hw/ ----> 5
# https://support.juniper.net/support/eol/product/ocx_series/ ----> 1
# https://support.juniper.net/support/eol/product/optics/ ----> 1
# https://support.juniper.net/support/eol/product/optics/ ----> 2
# https://support.juniper.net/support/eol/product/paragon_aa/ ----> 1
# https://support.juniper.net/support/eol/product/paragon_solution/ ----> 1
# https://support.juniper.net/support/eol/product/paragon_solution/ ----> 2
# https://support.juniper.net/support/eol/product/paragon_solution/ ----> 3
# https://support.juniper.net/support/eol/product/paragon_insights/ ----> 1
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 1
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 2
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 3
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 4
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 5
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 6
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 7
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 8
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 9
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 10
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 11
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 12
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 13
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 14
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 15
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 16
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 17
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 18
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 19
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 20
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 21
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 22
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 23
# https://support.juniper.net/support/eol/product/ptx_series/ ----> 24
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 1
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 2
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 3
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 4
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 5
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 6
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 7
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 8
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 9
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 10
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 11
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 12
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 13
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 14
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 15
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 16
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 17
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 18
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 19
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 20
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 21
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 22
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 23
# https://support.juniper.net/support/eol/product/qfx_series/ ----> 24
# https://support.juniper.net/support/eol/product/sbr_hw/ ----> 1
# https://support.juniper.net/support/eol/product/sbr_hw/ ----> 2
# https://support.juniper.net/support/eol/product/sdwan/ ----> 1
# https://support.juniper.net/support/eol/product/sdwan/ ----> 2
# https://support.juniper.net/support/eol/product/sdwan/ ----> 3
# https://support.juniper.net/support/eol/product/sd_cloud/ ----> 1
# https://support.juniper.net/support/eol/product/spotlight/ ----> 1
# https://support.juniper.net/support/eol/product/src/ ----> 1
# https://support.juniper.net/support/eol/product/src/ ----> 2
# https://support.juniper.net/support/eol/product/srx_series/ ----> 1
# https://support.juniper.net/support/eol/product/srx_series/ ----> 2
# https://support.juniper.net/support/eol/product/srx_series/ ----> 3
# https://support.juniper.net/support/eol/product/srx_series/ ----> 4
# https://support.juniper.net/support/eol/product/srx_series/ ----> 5
# https://support.juniper.net/support/eol/product/srx_series/ ----> 6
# https://support.juniper.net/support/eol/product/srx_series/ ----> 7
# https://support.juniper.net/support/eol/product/srx_series/ ----> 8
# https://support.juniper.net/support/eol/product/srx_series/ ----> 9
# https://support.juniper.net/support/eol/product/srx_series/ ----> 10
# https://support.juniper.net/support/eol/product/srx_series/ ----> 11
# https://support.juniper.net/support/eol/product/srx_series/ ----> 12
# https://support.juniper.net/support/eol/product/srx_series/ ----> 13
# https://support.juniper.net/support/eol/product/srx_series/ ----> 14
# https://support.juniper.net/support/eol/product/srx_series/ ----> 15
# https://support.juniper.net/support/eol/product/srx_series/ ----> 16
# https://support.juniper.net/support/eol/product/srx_series/ ----> 17
# https://support.juniper.net/support/eol/product/srx_series/ ----> 18
# https://support.juniper.net/support/eol/product/srx_series/ ----> 19
# https://support.juniper.net/support/eol/product/srx_series/ ----> 20
# https://support.juniper.net/support/eol/product/srx_series/ ----> 21
# https://support.juniper.net/support/eol/product/srx_series/ ----> 22
# https://support.juniper.net/support/eol/product/srx_series/ ----> 23
# https://support.juniper.net/support/eol/product/srx_series/ ----> 24
# https://support.juniper.net/support/eol/product/srx_series/ ----> 25
# https://support.juniper.net/support/eol/product/srx_series/ ----> 26
# https://support.juniper.net/support/eol/product/srx_series/ ----> 27
# https://support.juniper.net/support/eol/product/srx_series/ ----> 28
# https://support.juniper.net/support/eol/product/srx_series/ ----> 29
# https://support.juniper.net/support/eol/product/srx_series/ ----> 30
# https://support.juniper.net/support/eol/product/srx_series/ ----> 31
# https://support.juniper.net/support/eol/product/srx_series/ ----> 32
# https://support.juniper.net/support/eol/product/srx_series/ ----> 33
# https://support.juniper.net/support/eol/product/srx_series/ ----> 34
# https://support.juniper.net/support/eol/product/srx_series/ ----> 35
# https://support.juniper.net/support/eol/product/srx_series/ ----> 36
# https://support.juniper.net/support/eol/product/srx_series/ ----> 37
# https://support.juniper.net/support/eol/product/srx_series/ ----> 38
# https://support.juniper.net/support/eol/product/srx_series/ ----> 39
# https://support.juniper.net/support/eol/product/srx_series/ ----> 40
# https://support.juniper.net/support/eol/product/srx_series/ ----> 41
# https://support.juniper.net/support/eol/product/srx_series/ ----> 42
# https://support.juniper.net/support/eol/product/srx_series/ ----> 43
# https://support.juniper.net/support/eol/product/srx_series/ ----> 44
# https://support.juniper.net/support/eol/product/srx_series/ ----> 45
# https://support.juniper.net/support/eol/product/srx_series/ ----> 46
# https://support.juniper.net/support/eol/product/srx_series/ ----> 47
# https://support.juniper.net/support/eol/product/srx_series/ ----> 48
# https://support.juniper.net/support/eol/product/srx_series/ ----> 49
# https://support.juniper.net/support/eol/product/srx_series/ ----> 50
# https://support.juniper.net/support/eol/product/srx_series/ ----> 51
# https://support.juniper.net/support/eol/product/srx_series/ ----> 52
# https://support.juniper.net/support/eol/product/srx_series/ ----> 53
# https://support.juniper.net/support/eol/product/srx_series/ ----> 54
# https://support.juniper.net/support/eol/product/srx_series/ ----> 55
# https://support.juniper.net/support/eol/product/srx_series/ ----> 56
# https://support.juniper.net/support/eol/product/srx_series/ ----> 57
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 1
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 2
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 3
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 4
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 5
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 6
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 7
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 8
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 9
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 10
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 11
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 12
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 13
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 14
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 15
# https://support.juniper.net/support/eol/product/strm_jsa_series/ ----> 16
# https://support.juniper.net/support/eol/product/strm_series2/ ----> 1
# https://support.juniper.net/support/eol/product/t_series/ ----> 1
# https://support.juniper.net/support/eol/product/t_series/ ----> 2
# https://support.juniper.net/support/eol/product/t_series/ ----> 3
# https://support.juniper.net/support/eol/product/t_series/ ----> 4
# https://support.juniper.net/support/eol/product/t_series/ ----> 5
# https://support.juniper.net/support/eol/product/t_series/ ----> 6
# https://support.juniper.net/support/eol/product/t_series/ ----> 7
# https://support.juniper.net/support/eol/product/t_series/ ----> 8
# https://support.juniper.net/support/eol/product/t_series/ ----> 9
# https://support.juniper.net/support/eol/product/t_series/ ----> 10
# https://support.juniper.net/support/eol/product/t_series/ ----> 11
# https://support.juniper.net/support/eol/product/t_series/ ----> 12
# https://support.juniper.net/support/eol/product/t_series/ ----> 13
# https://support.juniper.net/support/eol/product/t_series/ ----> 14
# https://support.juniper.net/support/eol/product/t_series/ ----> 15
# https://support.juniper.net/support/eol/product/t_series/ ----> 16
# https://support.juniper.net/support/eol/product/t_series/ ----> 17
# https://support.juniper.net/support/eol/product/t_series/ ----> 18
# https://support.juniper.net/support/eol/product/t_series/ ----> 19
# https://support.juniper.net/support/eol/product/t_series/ ----> 20
# https://support.juniper.net/support/eol/product/t_series/ ----> 21
# https://support.juniper.net/support/eol/product/t_series/ ----> 22
# https://support.juniper.net/support/eol/product/t_series/ ----> 23
# https://support.juniper.net/support/eol/product/t_series/ ----> 24
# https://support.juniper.net/support/eol/product/t_series/ ----> 25
# https://support.juniper.net/support/eol/product/t_series/ ----> 26
# https://support.juniper.net/support/eol/product/t_series/ ----> 27
# https://support.juniper.net/support/eol/product/t_series/ ----> 28
# https://support.juniper.net/support/eol/product/t_series/ ----> 29
# https://support.juniper.net/support/eol/product/t_series/ ----> 30
# https://support.juniper.net/support/eol/product/t_series/ ----> 31
# https://support.juniper.net/support/eol/product/t_series/ ----> 32
# https://support.juniper.net/support/eol/product/t_series/ ----> 33
# https://support.juniper.net/support/eol/product/t_series/ ----> 34
# https://support.juniper.net/support/eol/product/t_series/ ----> 35
# https://support.juniper.net/support/eol/product/t_series/ ----> 36
# https://support.juniper.net/support/eol/product/t_series/ ----> 37
# https://support.juniper.net/support/eol/product/t_series/ ----> 38
# https://support.juniper.net/support/eol/product/t_series/ ----> 39
# https://support.juniper.net/support/eol/product/t_series/ ----> 40
# https://support.juniper.net/support/eol/product/t_series/ ----> 41
# https://support.juniper.net/support/eol/product/t_series/ ----> 42
# https://support.juniper.net/support/eol/product/t_series/ ----> 43
# https://support.juniper.net/support/eol/product/t_series/ ----> 44
# https://support.juniper.net/support/eol/product/t_series/ ----> 45
# https://support.juniper.net/support/eol/product/t_series/ ----> 46
# https://support.juniper.net/support/eol/product/t_series/ ----> 47
# https://support.juniper.net/support/eol/product/t_series/ ----> 48
# https://support.juniper.net/support/eol/product/t_series/ ----> 49
# https://support.juniper.net/support/eol/product/t_series/ ----> 50
# https://support.juniper.net/support/eol/product/t_series/ ----> 51
# https://support.juniper.net/support/eol/product/t_series/ ----> 52
# https://support.juniper.net/support/eol/product/t_series/ ----> 53
# https://support.juniper.net/support/eol/product/t_series/ ----> 54
# https://support.juniper.net/support/eol/product/t_series/ ----> 55
# https://support.juniper.net/support/eol/product/tca_series/ ----> 1
# https://support.juniper.net/support/eol/product/tcx_series/ ----> 1
# https://support.juniper.net/support/eol/product/vf_series/ ----> 1
# https://support.juniper.net/support/eol/product/vf_series/ ----> 2
# https://support.juniper.net/support/eol/product/vf_series/ ----> 3
# https://support.juniper.net/support/eol/product/vf_series/ ----> 4
# https://support.juniper.net/support/eol/product/vse_series/ ----> 1
# https://support.juniper.net/support/eol/product/vxa_series/ ----> 1
# https://support.juniper.net/support/eol/product/vxa_series/ ----> 2
# https://support.juniper.net/support/eol/product/vxa_series/ ----> 3
# https://support.juniper.net/support/eol/product/wandl/ ----> 1
# https://support.juniper.net/support/eol/product/wandl/ ----> 2
# https://support.juniper.net/support/eol/product/wandl/ ----> 3
# https://support.juniper.net/support/eol/product/wandl/ ----> 4
# https://support.juniper.net/support/eol/product/jwas_hw/ ----> 1
# https://support.juniper.net/support/eol/product/jwas_hw/ ----> 2
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 1
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 2
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 3
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 4
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 5
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 6
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 7
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 8
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 9
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 10
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 11
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 12
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 13
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 14
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 15
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 16
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 17
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 18
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 19
# https://support.juniper.net/support/eol/product/wlan_series/ ----> 20
# https://support.juniper.net/support/eol/product/wx_series/ ----> 1
# https://support.juniper.net/support/eol/product/wx_series/ ----> 2
# https://support.juniper.net/support/eol/product/wx_series/ ----> 3
# https://support.juniper.net/support/eol/product/wx_series/ ----> 4
# https://support.juniper.net/support/eol/product/wx_series/ ----> 5
# https://support.juniper.net/support/eol/product/wx_series/ ----> 6
# https://support.juniper.net/support/eol/product/wx_series/ ----> 7
# https://support.juniper.net/support/eol/product/wx_series/ ----> 8

# %%
# Remove values within brackets and trim whitespace in 'Product' and SKU column
final_df['Product'] = final_df['Product'].str.replace(r'\(.*\)', '').str.strip()
final_df['SKU'] = final_df['SKU'].str.replace(r'\(.*\)', '').str.strip()

# %%
#coalescing all headings to product
final_df['Product'].fillna(final_df['SKU'], inplace=True)
final_df['Product'].fillna(final_df['Product/SKU(s)'], inplace=True)

# Convert the 'Product' column to string type
final_df['Product'] = final_df['Product'].astype(str)

# Delete SKU Transformation Rows
final_df = final_df[~final_df['Product'].str.contains("SKU Transformation Announcement")]

# %%
final_df.drop(['SKU'], axis=1, inplace=True)
final_df.drop(['Product/SKU(s)'], axis=1, inplace=True)

# %%
# Transpose values in 'Product' column to separate rows
final_df = final_df.assign(Product = final_df['Product'].str.split(',')).explode('Product').reset_index(drop=True)

# Remove all unwanted HTML Tags present in the Products column
final_df['Product'] = final_df['Product'].apply(lambda x: re.sub('<[^<]+?>', '', x))

# %%
# Convert date columns to yyyy-mm-dd format
date_cols = ['EOL Announced', 'Last Order', 'Last Date to Convert Warranty', 'Same Day Support Discontinued', 'Next Day Support Discontinued', 'End of Support']
for col in date_cols:
    final_df[col] = pd.to_datetime(final_df[col], format='%m/%d/%Y', errors='coerce').dt.strftime('%Y-%m-%d')

# %% [markdown]
# ### Cleaning

# %%
#remove white spaces
final_df['Product'] = final_df['Product'].str.strip()

#Add refreshed date
final_df['refreshed_date']=pd.to_datetime('today')
final_df['refreshed_date']=final_df['refreshed_date'].dt.date

#remove empty products
final_df = final_df.dropna(subset=['Product'], how='any')

# %%
#remove empty products
final_df = final_df[final_df['Product'].apply(lambda x: str(x).strip()) != '']

# %%
#Export to Flat file
final_df.to_csv('Juniper_EOL.csv',index=False)
